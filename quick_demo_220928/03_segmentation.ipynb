# %%
import napari
from napari.utils import nbscreenshot

# %%
viewer = napari.Viewer()
nbscreenshot(viewer)
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events(6012, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(6012, 1)>
# Traceback (most recent call last):
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\site-packages\tornado\platform\asyncio.py", line 189, in _handle_events
#     handler_func(fileobj, events)
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\site-packages\zmq\eventloop\zmqstream.py", line 578, in _handle_events
#     self._handle_recv()
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\site-packages\zmq\eventloop\zmqstream.py", line 607, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\site-packages\zmq\eventloop\zmqstream.py", line 557, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\site-packages\jupyter_client\threaded.py", line 123, in _handle_recv
#     msg_list = self.ioloop._asyncio_event_loop.run_until_complete(get_msg(future_msg))
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\asyncio\base_events.py", line 622, in run_until_complete
#     self._check_running()
#   File "c:\Users\xcamra\anaconda3\envs\demo-env\lib\asyncio\base_events.py", line 584, in _check_running
#     raise RuntimeError(
# RuntimeError: Cannot run the event loop while another loop is running

# %% [markdown]
# To make it easy let us just look at a small area of the image

# %%
import skimage.io as skio
import numpy as np
import matplotlib.pyplot as plt
from skimage.exposure import histogram

rice = skio.imread("data/rice.tif", plugin="tifffile")
viewer.add_image(rice, name = 'rice')
viewer.layers['rice'].colormap = 'gray'
nbscreenshot(viewer)

# %% [markdown]
# skimage has its own imshow which is convenient while hacking things

# %%
plt.imshow(rice, cmap='gray')
plt.colorbar()
print('min pixel value: ', rice.min())
print('max pixel value: ', rice.max())
# Out:
# min pixel value:  33
# max pixel value:  214

# %% [markdown]
# Histograms are a common way of evaluating images and figuring out if the filtering/manipulations we are doing work

# %%
pix_counts, pix_vals = histogram(rice)
plt.bar(pix_vals, pix_counts, width = 10)
# Out:
# <BarContainer object of 182 artists>

# %% [markdown]
# Segmentation is the process of changing from images (gray scales) to binary masks, so we decide what is background and what is foreground. In other methods we might also have more than one class of interest

# %%
rice_mask = rice > 100
plt.imshow(rice_mask, cmap='gray')
plt.colorbar()

# %%
rice_mask = rice > 150
plt.imshow(rice_mask, cmap='gray')
plt.colorbar()

# %% [markdown]
# However we dont want to decide the th value by hand, there are many algorithms around, otsu is probably one of the most used one, together with triangle, and others

# %%
from skimage.filters import threshold_otsu

# %%
th_val = threshold_otsu(rice)
print('The value is: ', th_val)
bw_otsu = rice > th_val
plt.imshow(bw_otsu, cmap='gray')
plt.colorbar()
# Out:
# The value is:  131
